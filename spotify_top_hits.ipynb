# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
spotify <- read_csv("data/songs_normalize.csv")
spotify
# Out:
# Parsed with column specification:
# cols(
#   artist = col_character(),
#   song = col_character(),
#   duration_ms = col_double(),
#   explicit = col_logical(),
#   year = col_double(),
#   popularity = col_double(),
#   danceability = col_double(),
#   energy = col_double(),
#   key = col_double(),
#   loudness = col_double(),
#   mode = col_double(),
#   speechiness = col_double(),
#   acousticness = col_double(),
#   instrumentalness = col_double(),
#   liveness = col_double(),
#   valence = col_double(),
#   tempo = col_double(),
#   genre = col_character()
# )
#      artist              song
# 1    Britney Spears      Oops!...I Did It Again
# 2    blink-182           All The Small Things
# 3    Faith Hill          Breathe
# 4    Bon Jovi            It's My Life
# 5    *NSYNC              Bye Bye Bye
# 6    Sisqo               Thong Song
# 7    Eminem              The Real Slim Shady
# 8    Robbie Williams     Rock DJ
# 9    Destiny's Child     Say My Name
# 10   Modjo               Lady - Hear Me Tonight
# 11   Gigi D'Agostino     L'Amour Toujours
# 12   Eiffel 65           Move Your Body - Gabry Ponte Original Radio Edit
# 13   Bomfunk MC's        Freestyler
# 14   Sting               Desert Rose
# 15   Melanie C           Never Be The Same Again
# 16   Aaliyah             Try Again
# 17   Anastacia           I'm Outta Love - Radio Edit
# 18   Alice Deejay        Better Off Alone
# 19   Gigi D'Agostino     The Riddle
# 20   Dr. Dre             The Next Episode
# 21   Linkin Park         In the End
# 22   Tom Jones           Sexbomb
# 23   Sonique             It Feels So Good
# 24   M.O.P.              Cold as Ice
# 25   Melanie C           I Turn To You
# 26   Limp Bizkit         Take A Look Around
# 27   Darude              Sandstorm
# 28   Da Brat             What'chu Like (feat. Tyrese)
# 29   Moloko              The Time Is Now
# 30   Chicane             Don't Give Up
# ⋮    ⋮                   ⋮
# 1971 BTS                 Boy With Luv (feat. Halsey)
# 1972 Wiley               Boasty (feat. Idris Elba)
# 1973 Jonas Brothers      Only Human
# 1974 5 Seconds of Summer Easier
# 1975 Avicii              SOS (feat. Aloe Blacc)
# 1976 Tyler, The Creator  EARFQUAKE
# 1977 Ashley O            On A Roll
# 1978 Dominic Fike        3 Nights
# 1979 Sigala              Wish You Well
# 1999 0.0656      0.45000      1.97e-06         0.2220   0.347   102.998
# 2000 0.0395      0.19200      2.44e-03         0.0863   0.553   120.042
#      genre
# 1    pop
# 2    rock, pop
# 3    pop, country
# 4    rock, metal
# 5    pop
# 6    hip hop, pop, R&B
# 7    hip hop
# 8    pop, rock
# 9    pop, R&B
# 10   Dance/Electronic
# 11   pop
# 12   pop
# 13   pop
# 14   rock, pop
# 15   pop, Dance/Electronic
# 16   hip hop, pop, R&B
# 17   pop
# 18   pop
# 19   pop
# 20   hip hop
# 21   rock, metal
# 22   rock, Folk/Acoustic, easy listening
# 23   pop
# 24   hip hop
# 25   pop, Dance/Electronic
# 26   metal
# 27   pop, Dance/Electronic
# 28   hip hop, pop, R&B
# 29   pop, Dance/Electronic
# 30   Dance/Electronic
# ⋮    ⋮
# 1971 pop
# 1972 hip hop, Dance/Electronic
# 1973 pop
# 1974 pop
# 1975 pop, Dance/Electronic
# 1976 hip hop
# 1977 set()
# 1978 rock, pop
# 1979 pop, Dance/Electronic
# 1980 hip hop, pop, R&B
# 1981 latin
# 1982 pop, Dance/Electronic
# 1983 hip hop, pop, R&B
# 1984 latin
# 1985 hip hop
# 1986 pop
# 1987 pop, Dance/Electronic
# 1988 hip hop, pop
# 1989 rock
# 1990 pop, Dance/Electronic
# 1991 pop
# 1992 World/Traditional, hip hop
# 1993 pop, R&B
# 1994 pop, Dance/Electronic
# 1995 hip hop
# 1996 pop
# 1997 pop
# 1998 hip hop, country
# 1999 pop
# 2000 hip hop

# %%
# read + clean + wrangle data ----------------------------------------------------
single_genre <- c('country', 'latin', 'Dance/Electronic', 'Folk/Acoustic',
'pop', 'rock','hip hop','R&B','metal','jazz','blues','classical','World/Traditional')

# %%
song <- read_csv('https://raw.githubusercontent.com/nicolelassetter/DSCI100-project-g28/main/songs_normalize.csv') %>%
    mutate(genre <- as_factor(genre))%>%
    filter(genre %in% single_genre)
song
# Out:
# Parsed with column specification:
# cols(
#   artist = col_character(),
#   song = col_character(),
#   duration_ms = col_double(),
#   explicit = col_logical(),
#   year = col_double(),
#   popularity = col_double(),
#   danceability = col_double(),
#   energy = col_double(),
#   key = col_double(),
#   loudness = col_double(),
#   mode = col_double(),
#   speechiness = col_double(),
#   acousticness = col_double(),
#   instrumentalness = col_double(),
#   liveness = col_double(),
#   valence = col_double(),
#   tempo = col_double(),
#   genre = col_character()
# )
#     artist                song
# 1   Britney Spears        Oops!...I Did It Again
# 2   *NSYNC                Bye Bye Bye
# 3   Eminem                The Real Slim Shady
# 4   Modjo                 Lady - Hear Me Tonight
# 5   Gigi D'Agostino       L'Amour Toujours
# 6   Eiffel 65             Move Your Body - Gabry Ponte Original Radio Edit
# 7   Bomfunk MC's          Freestyler
# 8   Anastacia             I'm Outta Love - Radio Edit
# 9   Alice Deejay          Better Off Alone
# 10  Gigi D'Agostino       The Riddle
# 11  Dr. Dre               The Next Episode
# 12  Sonique               It Feels So Good
# 13  M.O.P.                Cold as Ice
# 14  Limp Bizkit           Take A Look Around
# 15  Chicane               Don't Give Up
# 16  Madonna               Music
# 17  Ruff Endz             No More
# 686 0.2210      0.4890       0.00e+00         0.0977   0.618   175.813
# 687 0.0685      0.2300       5.98e-06         0.7950   0.413    79.635
# 688 0.1260      0.6020       8.53e-03         0.1360   0.706    91.987
# 689 0.3410      0.1360       1.59e-04         0.1100   0.619   176.044
# 690 0.0400      0.3310       0.00e+00         0.1350   0.341   145.038
# 691 0.1200      0.2140       0.00e+00         0.0669   0.607    95.005
# 692 0.0618      0.1930       0.00e+00         0.0640   0.681    82.014
# 693 0.0925      0.1530       0.00e+00         0.0763   0.345   110.567
# 694 0.0745      0.4470       0.00e+00         0.1110   0.175   150.231
# 695 0.0588      0.0427       0.00e+00         0.1060   0.952   137.958
# 696 0.1570      0.1170       2.06e-05         0.1050   0.564   169.994
# 697 0.0656      0.4500       1.97e-06         0.2220   0.347   102.998
# 698 0.0395      0.1920       2.44e-03         0.0863   0.553   120.042
#     genre            genre <- as_factor(genre)
# 1   pop              pop
# 2   pop              pop
# 3   hip hop          hip hop
# 4   Dance/Electronic Dance/Electronic
# 5   pop              pop
# 6   pop              pop
# 7   pop              pop
# 8   pop              pop
# 9   pop              pop
# 10  pop              pop
# 11  hip hop          hip hop
# 12  pop              pop
# 13  hip hop          hip hop
# 14  metal            metal
# 15  Dance/Electronic Dance/Electronic
# 16  pop              pop
# 17  R&B              R&B
# 18  pop              pop
# 19  hip hop          hip hop
# 20  hip hop          hip hop
# 21  pop              pop
# 22  pop              pop
# 23  R&B              R&B
# 24  hip hop          hip hop
# 25  R&B              R&B
# 26  pop              pop
# 27  pop              pop
# 28  pop              pop
# 29  rock             rock
# 30  pop              pop
# ⋮   ⋮                ⋮
# 669 latin            latin
# 670 pop              pop
# 671 pop              pop
# 672 hip hop          hip hop
# 673 pop              pop
# 674 pop              pop
# 675 hip hop          hip hop
# 676 pop              pop
# 677 pop              pop
# 678 pop              pop
# 679 latin            latin
# 680 pop              pop
# 681 hip hop          hip hop
# 682 hip hop          hip hop
# 683 hip hop          hip hop
# 684 pop              pop
# 685 pop              pop
# 686 pop              pop
# 687 hip hop          hip hop
# 688 latin            latin
# 689 latin            latin
# 690 hip hop          hip hop
# 691 pop              pop
# 692 rock             rock
# 693 pop              pop
# 694 hip hop          hip hop
# 695 pop              pop
# 696 pop              pop
# 697 pop              pop
# 698 hip hop          hip hop

# %%
# split data to Training + Testing Data ---------------------------------------------
song_split <- initial_split(song, prop = 0.75, strata = explicit)
song_train <- training(song_split)
track_test <- testing(song_split)

# %%
# summarise only training data info into tables ----------------------------------------
n_genre_table_training <- song_train %>%
    group_by(genre, explicit) %>%
    summarize(n = n()) #%>%
    #pivot_wider(names_from = explicit, values_from = n)
n_genre_table_training
# Out:
# `summarise()` regrouping output by 'genre' (override with `.groups` argument)
#    genre            explicit n
# 1  country          FALSE     10
# 2  Dance/Electronic FALSE     24
# 3  Dance/Electronic  TRUE      4
# 4  hip hop          FALSE     14
# 5  hip hop           TRUE     83
# 6  latin            FALSE      8
# 7  latin             TRUE      3
# 8  metal            FALSE      6
# 9  metal             TRUE      2
# 10 pop              FALSE    280
# 11 pop               TRUE     39
# 12 R&B              FALSE      7
# 13 R&B               TRUE      2
# 14 rock             FALSE     38
# 15 rock              TRUE      4

# %%
mean_table_training <- song_train %>%
    select(speechiness, acousticness, energy, danceability) %>%
    map_df(mean)

# %%
# Using training data: visualise data to find possible predictors relevant for analysis ----

# Bar: genre vs count (Number of Songs Total)
plot1 <- n_genre_table_training %>%
    ggplot(aes(x = genre, fill = explicit, y = n)) +
    geom_bar(stat = 'identity') +
    labs(x = "Single Song Genres", y = 'Number of Songs Total') +
    ggtitle('Single Song Genres vs Number of Songs Total Colored by Explicit')
plot1
# Out:
# plot without title

# %%
# Scatter: Speechiness vs Energy Colored and Shaped by Explicit
plot2 <- song_train %>%
    ggplot(aes(x = energy, y = speechiness, colour = explicit, shape = explicit)) +
    geom_point() +
    labs(x = "Energy (Scale from 0-1)", y = 'Speechiness (Scale from 0-1)') +
    ggtitle('Speechiness vs Energy Colored and Shaped by Explicit')
plot2
# Out:
# plot without title

# %%
# Scatter: Speechiness vs Danceability Colored and Shaped by Explicit
plot3 <- song_train %>%
    ggplot(aes(x = danceability, y = speechiness, colour = explicit, shape = explicit)) +
    geom_point() +
    labs(x = "Danceability (Scale from 0-1)", y = 'Speechiness (Scale from 0-1)') +
    ggtitle('Speechiness vs Danceability Colored and Shaped by Explicit')
plot3
# Out:
# plot without title

# %%
# Scatter : Speechiness vs Acousticness Colored and Shaped by Explicit
plot4 <- song_train %>%
    ggplot(aes(x = acousticness, y = speechiness, colour = explicit, shape = explicit)) +
    geom_point() +
    labs(x = "Danceability (Scale from 0-1)", y = 'Speechiness (Scale from 0-1)') +
    ggtitle('Speechiness vs Acousticness Colored and Shaped by Explicit')
plot4
# Out:
# plot without title

# %%
## Plots that shows little to no relationship to explicitness
p00 <- ggplot(song_train,aes(x = popularity,color = explicit))+geom_bar()+scale_fill_brewer(palette = "Set1")
p01 <- ggplot(song_train,aes(x = year,color = explicit))+geom_bar()+scale_fill_brewer(palette = "Set1")
p02 <- ggplot(song_train,aes(x = energy ,color = explicit))+geom_bar()+scale_fill_brewer(palette = "Set1")
p03 <- ggplot(song_train,aes(x = loudness,color = explicit))+geom_bar()+scale_fill_brewer(palette = "Set1")
p04 <- ggplot(song_train,aes(x = mode ,color = explicit))+geom_bar()+scale_fill_brewer(palette = "Set1")
p05 <- ggplot(song_train,aes(x = valence ,color = explicit))+geom_histogram()
p06 <- ggplot(song_train,aes(x = danceability ,color = explicit))+geom_histogram()
p07 <- ggplot(song_train,aes(x = popularity ,color = explicit))+geom_histogram()
p08 <- ggplot(song_train,aes(x = key ,color = explicit))+geom_histogram()
p09 <- ggplot(song_train,aes(x = loudness ,color = explicit))+geom_histogram()
p10 <- ggplot(song_train,aes(x = acousticness ,color = explicit))+geom_histogram()
p11 <- ggplot(song_train,aes(x = instrumentalness ,color = explicit))+geom_histogram()
p12 <- ggplot(song_train,aes(x = liveness ,color = explicit))+geom_histogram()
p13 <- ggplot(song_train,aes(x = valence ,color = explicit))+geom_histogram()
p14 <- ggplot(song_train,aes(x = tempo ,color = explicit))+geom_histogram()
p15 <- ggplot(song_train,aes(x = genre ,color = explicit))+geom_bar()
